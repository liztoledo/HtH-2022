# %%
import pandas as pd
import re
import numpy as np

pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

#pd.options.display.max_columns = None
#pd.options.display.max_rows = None

# %%
# Step 1: We want to import out csv file and view our dataset

top200_data = pd.read_csv("spotify_dataset.csv")

#drop Index and Song ID column
top200_data = top200_data.drop(columns=["Index", "Song ID"])
top200_data
# Out:
#       Highest Charting Position  Number of Times Charted  \
# 0                             1                        8
# 1                             2                        3
# 2                             1                       11
# 3                             3                        5
# 4                             5                        1
# 5                             1                       18
# 6                             3                       16
# 7                             2                       10
# 8                             3                        8
# 9                             8                       10
# 10                            4                       43
# 11                            9                        9
# 12                            5                        3
# 13                            1                       19
# 14                            2                       10
# ...

# %% [markdown]
# # Spotify Top 200 Chart Data Features Key
# - Highest Charting Position
# - Number of times charted

# %%
# Step 2: We want to outline the questions we will be addressing through our data analysis.

# %% [markdown]
# #### 1. Which latin artists made it on the charts the most?
# #### 2. Which latin artists made it on the charts the fastest since their songs' release date? Include the song titles.
# #### 3. During which months were the top 200 charting latin songs released?
# #### 4. Which latin songs charted during the summer months?
# #### 5.Which of above songs are the top 5 highest in popularity and danceability?
# #### 6. Which genres are the 5 highest ranked in popularity during the summer months?
# #### 7. Which artist popped up on the 200 charts the most? What was the duration of their longest song?
# #### 8. Does a higher danceability score have a relationship to the song popularity?
# #### 9. Based on the highest streaming songs, what chords were most popular?
# #### 10. Do songs with lower instumentalness values chart lower or have lower streams?

# %% [markdown]
# # Latin Artists and Music on the Chart

# %% [markdown]
# First, I will have to find the Latin artists in this large dataset. I will narrow down my search by creating a table with songs that contains the substring "latin" in one of the genre titles.

# %%
#Isolate the rows with the substring "latin" in one of the list items for songs' genres (this accounts for variations)  
contains_latin = top200_data['Genre'].str.contains("latin")
contains_latin
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [11], in <cell line: 2>()
#       1 #Isolate the rows with the substring "latin" in one of the list items for songs' genres (this accounts for variations)
# ----> 2 contains_latin = top200_data['Genre'].str.contains("latin", "espanol", "reggaeton")
#       3 contains_latin
#
# File /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/pandas/core/strings/accessor.py:125, in forbid_nonstring_types.<locals>._forbid_nonstring_types.<locals>.wrapper(self, *args, **kwargs)
#     120     msg = (
#     121         f"Cannot use .str.{func_name} with values of "
#     122         f"inferred dtype '{self._inferred_dtype}'."
#     123     )
#     124     raise TypeError(msg)
# --> 125 return func(self, *args, **kwargs)
#
# ...

# %%
# Add the

# %%
#Create a column of booleans that say whether the Genre contains "latin"
top200_data["Includes Latin"] = contains_latin

# %%
#Creates a df of just songs containing "latin" in the Genre column
latin_genre = top200_data[top200_data["Includes Latin"] == True]
latin_genre
# Out:
#       Highest Charting Position  Number of Times Charted  \
# 7                             2                       10
# 8                             3                        8
# 11                            9                        9
# 18                           14                        5
# 20                           19                        3
# 26                           27                        3
# 33                           10                       15
# 38                           39                        3
# 39                            1                       39
# 40                           41                       13
# 42                           33                        6
# 48                           29                        6
# 50                           19                        4
# 57                           31                       12
# 68                           69                        3
# ...

# %%
latin_genre.shape
# Out:
# (194, 22)

# %%
#Create a for loop with all the songs with the string "latin" showing up in one of the genre descriptions. 
#latin_song_data = []
#latin_in_genre = []

#for index, row in top200_data.iterrows():
    #if "latin" in row["Genre"]:
        #latin_song_data.append(row)
        #latin_in_genre.append(row("Song Name") + "by " + row("Artist"))

#latin_songs = pd.DataFrame(latin_song_data)
#type(latin_songs)

# %%
#charted_latin_artists = latin_songs.groupby("Artist").agg(np.size)[["Word Mark"]].sort_values("Word Mark", ascending = False)
